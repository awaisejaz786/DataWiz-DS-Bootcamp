# %% [markdown]
# <a href="https://colab.research.google.com/github/awaisejaz786/DataWiz-DS-Bootcamp/blob/master/assignment_class_1_(Part1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Questions
#
#
# 1. What is the difference between the `/` and the `//` operators?
#
# **Ans.** *`/` divides the two integers or float values `//` gives you a round value  after division*
#
# 2. What is the difference between the `*` and the `**` operators?
#
# **Ans.** `*` *multiplies two numbers and `**` gives square or power of that number*
#
# 3. What is the order of precedence for arithmetic operators in Python?
#
# **Ans.** *All the operators have left-to-right associativity.*
#
# 4. How do you specify the order in which arithmetic operations are performed in an expression involving multiple operators?
#
# **Ans.** *Parenthesis are performed First then, Exponentiation is performed  (when available), multiplication and division are performed next, addition and subtraction are performed last.*
#
# 12. How do you solve a multi-step arithmetic word problem using Python?
#
# **Ans.**
# 13. What are variables? Why are they useful?
#
# **Ans.*** Recall that a variable is a label for a location in memory. It can be used to hold a value. In statically typed languages, variables have predetermined types, and a variable can only be used to hold values of that type. In Python, we may reuse the same variable to store values of any type.
#
# 14. How do you create a variable in Python?
#
# **Ans.** Python lets you create variables simply by assigning a value to the variable, without the need to declare the variable upfront. The value assigned to a variable determines the variable type.
#
# 15. What is the assignment operator in Python?
#
# **Ans.** Assignment operators are used in Python to assign values to variables.
# 16. What are the rules for naming a variable in Python?
#
# **Ans.*** Rules for Python variables:
#
# *   A variable name must start with a letter or the underscore character
# *   A variable name cannot start with a number
# *   A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# *   Variable names are case-sensitive (age, Age and AGE are three different variables)
#
# 17. How do you view the value of a variable?
#
# **Ans.***Variables may be shown on the screen using the print() function.
#
# 18. How do you store the result of an arithmetic expression in a variable?
# **Ans.*** *a=1+2*
#
# 19. What happens if you try to access a variable that has not been defined?
#
# **Ans.** *Attempting to access a variable that hasn't previously been defined raises a NameError exception*
#
# 20. How do you display messages in Python?
#
# **Ans.** *Python print() can be used to show a message in the Python*
#
# 21. What types of inputs can the print function accept?
#
# **Ans.** *It accepts list, tuple, int and all other data types*
#
# 22. What are code comments? How are they useful?
#
# **Ans.** *A comment is a programmer-readable explanation or annotation in the source code of a computer program. They are added with the purpose of making the source code easier for humans to understand, and are generally ignored by compilers and interpreters.*
#
# 23. What are the different ways of creating comments in Python code?
#
# **Ans.** *In Python, there are two ways to annotate your code. The first is to include comments that detail or indicate what a section of code – or snippet – does. The second makes use of multi-line comments or paragraphs that serve as documentation for others reading your code.*
#
# 24. What are the different comparison operations supported in Python?
#
# **Ans.** *(> , < , >= , <= , = , =!)*
#
# 25. What is the result of a comparison operation?
#
# **Ans.** *True and False*
#
# 26. What is the difference between `=` and `==` in Python?
#
# **Ans.** *The Equality operator `==` compares the values of both the operands and checks for value equality. and `=` is used to assign value to a variable.*
#
# 27. What are the logical operators supported in Python?
#
# **Ans.** *AND, OR , NOT*
#
# 28. What is the difference between the `and` and `or` operators?
#
# **Ans.** *When we use AND to combine two or more than two conditions, records satisfying all the specified conditions will be there in the result.*
#
# *But in case of OR operator, atleast one condition from the conditions specified must be satisfied by any record to be in the resultset.*
#
#
#
# 29. Can you use comparison and logical operators in the same expression?
#
# **Ans.** *Yes we can*
#
# 30. What is the purpose of using parentheses in arithmetic or logical expressions?
#
# **Ans.** *Parentheses are used to control the order in which operators are evaluated.*
